# %% [markdown]
# <a href="https://colab.research.google.com/github/prachip4013-ctrl/Prachi/blob/main/Welcome_to_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1.To calculate length of string

s = input("Enter string: ")
print(s[:2] + s[-2:])
#OUTPUT
Learning

#2. To make string from first and last two characters from given string

s = input("Enter string: ")
print(s[:2] + s[-2:])
#OUTPUT
Compute

#3. To concatenate two strings

a = input("First: ")
b = input("Second: ")
print(a + b)
#OUTPUT
Opensource
