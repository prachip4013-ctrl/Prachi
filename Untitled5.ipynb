# %% [markdown]
# <a href="https://colab.research.google.com/github/prachip4013-ctrl/Prachi/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Taking two numbers
a = 15
b = 5
sum_result = a + b
print("sum =", sum_result)

# Declare variables
a = 2         # integer
b = 1.3       # float
c = "Hello"   # string

# Display variables
print("value of a :", a)
print("value of b :", b)
print("value of c :", c)

# Display types of variables
print("type of a :", type(a))
print("type of b :", type(b))
print("type of c :", type(c))

# Declare variables
a = 10        # integer
b = 6.7       # float

# Type casting
x = float(a)  # int to float
y = int(b)    # float to int

# Display result
print("original value of a :", a, "Type :", type(a))
print("After casting a to float :", x, "Type :", type(x))
print("After casting b to int :", y, "Type :", type(y))

# Declare variables
a = 10
b = 5

# Logical AND
print("a > 5 and b > 2 :", a > 5 and b > 2)

# Logical OR
print("a > 15 or b > 2 :", a > 15 or b > 2)
# Out:
# sum = 20
# value of a : 2
# value of b : 1.3
# value of c : Hello
# type of a : <class 'int'>
# type of b : <class 'float'>
# type of c : <class 'str'>
# original value of a : 10 Type : <class 'int'>
# After casting a to float : 10.0 Type : <class 'float'>
# After casting b to int : 6 Type : <class 'int'>
# a > 5 and b > 2 : True
# a > 15 or b > 2 : True
